# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('../')))
from src.to_postgres import load_json_to_postgres

# %%
load_json_to_postgres()
# Out:
# Successfully loaded 200 rows to raw.telegram_messages
