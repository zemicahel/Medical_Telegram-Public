# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('../')))
from src.to_postgres import load_json_to_postgres , load_yolo_to_postgres
from src.yolo_detect import run_detection

# %%
load_json_to_postgres(),
load_yolo_to_postgres()
# Out:
# Searching for JSON in: /Users/mac/Documents/kaim/medical-telegram-warehouse/notebooks/data/raw/telegram_messages
# Table raw.telegram_messages truncated.
# Successfully loaded 400 rows to raw.telegram_messages
# Successfully loaded 216 rows to detection.yolo_results
